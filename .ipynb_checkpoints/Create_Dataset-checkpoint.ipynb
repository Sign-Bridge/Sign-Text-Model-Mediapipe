# %%
import os
import cv2
import mediapipe as mp
import matplotlib.pyplot as plt

# %%
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles

# %%
hands = mp_hands.Hands(static_image_mode=True, min_detection_confidence=0.3)

# %%
DATA_DIR = 'E:\EAC\Project\Dataset\data' #dtaset directory

# %%
for directory in os.listdir(DATA_DIR):
    for img_path in os.listdir(os.path.join(DATA_DIR, directory))[:1]:
        img = cv2.imread(os.path.join(DATA_DIR, directory, img_path))
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        results = hands.process(img_rgb)
        if results.multi_hand_landmarks:
            for handLms in results.multi_hand_landmarks:
                #mp_drawing.draw_landmarks(img_rgb, handLms, mp_hands.HAND_CONNECTIONS, mp_drawing_styles.get_default_hand_landmarks_style(), mp_drawing_styles.get_default_hand_connections_style())
                
        #plt.figure()
        #plt.imshow(img_rgb)
        
#plt.show()
                for i in range(len(handLms)):
                    print(handLms.landmark[i])
# Out:
# landmark {
#   x: 0.479103684425354
#   y: 0.8575274348258972
#   z: -4.784299107996048e-07
# }
# landmark {
#   x: 0.40240412950515747
#   y: 0.7885556221008301
#   z: -0.07645957171916962
# }
# landmark {
#   x: 0.36329108476638794
#   y: 0.6745451092720032
#   z: -0.12664707005023956
# }
# landmark {
#   x: 0.4161500334739685
#   y: 0.5874351859092712
#   z: -0.17331022024154663
# }
# landmark {
#   x: 0.4988294243812561
#   y: 0.540576696395874
#   z: -0.21563935279846191
# }
# landmark {
#   x: 0.41813692450523376
#   y: 0.48266956210136414
#   z: -0.08794258534908295
# }
# landmark {
#   x: 0.40128982067108154
#   y: 0.31470394134521484
#   z: -0.16703075170516968
# }
# landmark {
#   x: 0.38980841636657715
#   y: 0.21387550234794617
#   z: -0.21372449398040771
# }
# landmark {
#   x: 0.38817456364631653
#   y: 0.12369132041931152
#   z: -0.24674461781978607
# }
# landmark {
#   x: 0.5169854760169983
#   y: 0.5219506025314331
#   z: -0.0951785296201706
# }
# landmark {
#   x: 0.5410123467445374
#   y: 0.44523489475250244
#   z: -0.20333465933799744
# }
# landmark {
#   x: 0.496837317943573
#   y: 0.5644871592521667
#   z: -0.21931420266628265
# }
# landmark {
#   x: 0.4824003577232361
#   y: 0.6229960918426514
#   z: -0.20615963637828827
# }
# landmark {
#   x: 0.5980595946311951
#   y: 0.5859860777854919
#   z: -0.1126612201333046
# }
# landmark {
#   x: 0.6066135764122009
#   y: 0.5479259490966797
#   z: -0.2136562466621399
# }
# landmark {
#   x: 0.5361043214797974
#   y: 0.6602553129196167
#   z: -0.18107885122299194
# }
# landmark {
#   x: 0.513719379901886
#   y: 0.700928807258606
#   z: -0.13482020795345306
# }
# landmark {
#   x: 0.6639920473098755
#   y: 0.6646844148635864
#   z: -0.13797995448112488
# }
# landmark {
#   x: 0.6694961786270142
#   y: 0.6270043849945068
#   z: -0.20058955252170563
# }
# landmark {
#   x: 0.6048557758331299
#   y: 0.7031163573265076
#   z: -0.17215941846370697
# }
# landmark {
#   x: 0.5773294568061829
#   y: 0.7319434881210327
#   z: -0.13684068620204926
# }
#
# landmark {
#   x: 0.46504560112953186
#   y: 0.8801524639129639
#   z: 1.0205305898125516e-06
# }
# landmark {
#   x: 0.3720529079437256
#   y: 0.8012295961380005
#   z: -0.0876692458987236
# }
# landmark {
#   x: 0.3572015166282654
#   y: 0.6722153425216675
#   z: -0.13357311487197876
# }
# landmark {
#   x: 0.4616306722164154
#   y: 0.5770629644393921
#   z: -0.17655567824840546
# }
# landmark {
#   x: 0.5595045685768127
#   y: 0.5096365809440613
#   z: -0.2150670289993286
# }
# landmark {
#   x: 0.37035277485847473
#   y: 0.4612024128437042
#   z: -0.068802110850811
# }
# landmark {
#   x: 0.33700689673423767
#   y: 0.28408095240592957
#   z: -0.12889844179153442
# }
# landmark {
#   x: 0.32099032402038574
#   y: 0.17113955318927765
#   z: -0.17075246572494507
# }
# landmark {
#   x: 0.3106965720653534
#   y: 0.07994040846824646
#   z: -0.19980604946613312
# }
# landmark {
#   x: 0.4766538441181183
#   y: 0.4647056758403778
#   z: -0.0730052962899208
# }
# landmark {
#   x: 0.5150681734085083
#   y: 0.2698657512664795
#   z: -0.13306383788585663
# }
# landmark {
#   x: 0.5325586795806885
#   y: 0.15290385484695435
#   z: -0.1801818460226059
# }
# landmark {
#   x: 0.5485040545463562
#   y: 0.05525928735733032
#   z: -0.20924539864063263
# }
# landmark {
#   x: 0.5580766797065735
#   y: 0.5202771425247192
#   z: -0.08792310208082199
# }
# landmark {
#   x: 0.6141266822814941
#   y: 0.40157637000083923
#   z: -0.17832747101783752
# }
# landmark {
#   x: 0.5652015209197998
#   y: 0.4800894558429718
#   z: -0.20556268095970154
# }
# landmark {
#   x: 0.5288285613059998
#   y: 0.5444018840789795
#   z: -0.20263810455799103
# }
# landmark {
#   x: 0.6199796199798584
#   y: 0.6027035117149353
#   z: -0.10867569595575333
# }
# landmark {
#   x: 0.6375157833099365
#   y: 0.5202311277389526
#   z: -0.18421798944473267
# }
# landmark {
#   x: 0.5835829973220825
#   y: 0.5737783312797546
#   z: -0.192853644490242
# }
# landmark {
#   x: 0.5413526296615601
#   y: 0.6282942295074463
#   z: -0.18444356322288513
# }
